# %%
# !train.py
# Out:
# Start training
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# cuda:0 cuda:0
# Train Epoch: 1 Loss: 0.017834 Acc: 0.31%
# Validation Loss: 5.028362 Acc: 0.00%
# Best validation accuracy: 0.00%
